# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.5017, 0.4001, 0.9336],
#         [0.2298, 0.3414, 0.1333],
#         [0.4753, 0.6671, 0.5101],
#         [0.7826, 0.3646, 0.9928],
#         [0.5561, 0.3943, 0.7643]])
